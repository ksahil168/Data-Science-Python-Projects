# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

pd.pandas.set_option('display.max_columns', None)

# %%
df = pd.read_csv('train.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.shape
# Out:
# (1460, 81)

# %%
features_with_na=[features for features in df.columns if df[features].isnull().sum()>1]

for features in features_with_na:
    print(features, np.round(df[features].isnull().mean(),4), '%')
# Out:
# LotFrontage 0.1774 %
# Alley 0.9377 %
# MasVnrType 0.0055 %
# MasVnrArea 0.0055 %
# BsmtQual 0.0253 %
# BsmtCond 0.0253 %
# BsmtExposure 0.026 %
# BsmtFinType1 0.0253 %
# BsmtFinType2 0.026 %
# FireplaceQu 0.4726 %
# GarageType 0.0555 %
# GarageYrBlt 0.0555 %
# GarageFinish 0.0555 %
# GarageQual 0.0555 %
# GarageCond 0.0555 %
# PoolQC 0.9952 %
# Fence 0.8075 %
# MiscFeature 0.963 %

# %%
for feaures in features_with_na:
    df2 = df.copy()
    
    df2[features] = np.where(df2[features].isnull(),1,0)    
    
    df2.groupby(features)['SalePrice'].median().plot.bar()
    plt.show()

# %%
len(df2.Id)
# Out:
# 1460

# %%
numeric = [features for features in df2.columns if df2[features].dtypes != object]
len(numeric)
numeric
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscFeature',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
year = df2[numeric].filter(like =  'Y')

# %%
year_feature =list(year)
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for features in year:
    print(year)
# Out:
#       YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# 0          2003          2003       2003.0    2008
# 1          1976          1976       1976.0    2007
# 2          2001          2002       2001.0    2008
# 3          1915          1970       1998.0    2006
# 4          2000          2000       2000.0    2008
# ...         ...           ...          ...     ...
# 1455       1999          2000       1999.0    2007
# 1456       1978          1988       1978.0    2010
# 1457       1941          2006       1941.0    2010
# 1458       1950          1996       1950.0    2010
# 1459       1965          1965       1965.0    2008
#
# [1460 rows x 4 columns]
#       YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# 0          2003          2003       2003.0    2008
# 1          1976          1976       1976.0    2007
# 2          2001          2002       2001.0    2008
# 3          1915          1970       1998.0    2006
# 4          2000          2000       2000.0    2008
# ...

# %%
corr = df2[numeric].corr()
sns.heatmap(corr, annot=False, cmap="YlOrBr")
plt.figure(figsize=(50, 50))

# %%
(x='YrSold',y= 'SalePrice',data=df2)
# Out:
# <AxesSubplot:xlabel='YrSold', ylabel='SalePrice'>

# %%
df2.groupby('YrSold')['SalePrice'].median().plot()
# Out:
# <AxesSubplot:xlabel='YrSold'>

# %%
df2[features].unique()
# Out:
# array([2008, 2007, 2006, 2009, 2010], dtype=int64)

# %%
discrete_feature=[features for features in numeric if len(df2[features].unique())<25 and features not in year_feature +['Id']]
print("Discrete Variables Count: {}".format(len(discrete_feature)))
# Out:
# Discrete Variables Count: 18

# %%
discrete_feature
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscFeature',
#  'MiscVal',
#  'MoSold']

# %%
df2[discrete_feature].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscFeature  MiscVal  MoSold
# ...

# %%
for features in discrete_feature:
    
    df2.groupby(features)['SalePrice'].median().plot.bar()
    plt.show()

# %%
##ContinousVariable

# %%
continuous_feature = [features for features in numeric if features not in discrete_feature + year_feature + ['Id']]

# %%
len(continuous_feature)
# Out:
# 16

# %%
for features in continuous_feature:
    df2[features].hist(bins=25)
    plt.show()
