# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
import plotly.express as px
import plotly.figure_factory as ff

# %%
## Install opendatsets library to downlaod the data from kaggle by using link of the data
## !pip install opendatasets --upgrade --quiet
import opendatasets as od 

##Kaggle Dataset URL
datasets_url = 'https://www.kaggle.com/peopledatalabssf/free-7-million-company-dataset'

## Downloading the dataset
od.download(datasets_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: kumarsahil222
# Your Kaggle Key: ········
#   0%|                                                                                       | 0.00/278M [00:00<?, ?B/s]
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 278M/278M [01:36<00:00, 3.02MB/s]

# %%
# Convert dataset into CSV file
datasets_url_to_csv = '/content/free-7-million-company-dataset/companies_sorted.csv'
datasets_url_to_csv
# Out:
# '/content/free-7-million-company-dataset/companies_sorted.csv'

# %%
data = pd.read_csv('free-7-million-company-dataset/companies_sorted.csv')
data
# Out:
#          Unnamed: 0                            name  \
# 0           5872184                             ibm
# 1           4425416       tata consultancy services
# 2             21074                       accenture
# 3           2309813                         us army
# 4           1558607                              ey
# ...             ...                             ...
# 7173421     1494427              certiport vouchers
# 7173422     1494429          black tiger fight club
# 7173423     4768462      catholic bishop of chicago
# 7173424     1494436             medexo robotics ltd
# 7173425     2842728  dynamic controls solutions inc
#
#                                domain  year founded  \
# 0                             ibm.com        1911.0
# 1                             tcs.com        1968.0
# 2                       accenture.com        1989.0
# 3                          goarmy.com        1800.0
# 4                              ey.com        1989.0
# ...

# %%
data2.head(10)
# Out:
#    Unnamed: 0                            name              domain    year  \
# 0     5872184                             ibm             ibm.com  1911.0
# 1     4425416       tata consultancy services             tcs.com  1968.0
# 2       21074                       accenture       accenture.com  1989.0
# 3     2309813                         us army          goarmy.com  1800.0
# 4     1558607                              ey              ey.com  1989.0
# 5     3844889                 hewlett-packard             hpe.com  1939.0
# 6     2959148  cognizant technology solutions       cognizant.com  1994.0
# 7     5944912                         walmart  walmartcareers.com  1962.0
# 8     3727010                       microsoft       microsoft.com  1975.0
# 9     3300741                            at&t             att.com  1876.0
#
#                               industry size range  \
# 0  information technology and services     10001+
# 1  information technology and services     10001+
# ...

# %%
df.rename(columns = { 'year_founded' : 'year'}, inplace = True)
df
# Out:
#            ID                                            name  \
# 0     5872184                                             ibm
# 1     4425416                       tata consultancy services
# 2       21074                                       accenture
# 3     2309813                                         us army
# 4     1558607                                              ey
# ...       ...                                             ...
# 9995  3585785  university of chicago booth school of business
# 9996  2583172                      pantaloon retail india ltd
# 9997  1406043                                       nv energy
# 9998   955441                                          mining
# 9999  5571765                          university of stirling
#
#                 domain    year                             industry  \
# 0              ibm.com  1911.0  information technology and services
# 1              tcs.com  1968.0  information technology and services
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'name', 'domain', 'year', 'industry', 'size range',
#        'locality', 'country', 'linkedin url', 'current employee estimate',
#        'total employee estimate'],
#       dtype='object')

# %%
##data2=data
## lets work with 10000 data

# Convert the data data into CSV file
##data2.to_csv('data2.csv')

## bring 10000 rows
df = pd.read_csv('data2.csv', index_col = 0,  nrows = 10000)

# %%
df.rename(columns = { 'Unnamed: 0.1' : 'ID'}, inplace = True)
df
# Out:
#            ID                                            name  \
# 0     5872184                                             ibm
# 1     4425416                       tata consultancy services
# 2       21074                                       accenture
# 3     2309813                                         us army
# 4     1558607                                              ey
# ...       ...                                             ...
# 9995  3585785  university of chicago booth school of business
# 9996  2583172                      pantaloon retail india ltd
# 9997  1406043                                       nv energy
# 9998   955441                                          mining
# 9999  5571765                          university of stirling
#
#                 domain  year founded                             industry  \
# 0              ibm.com        1911.0  information technology and services
# ...

# %%
df.columns = df.columns.str.replace('\s+', '_')

# %%
data.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2962204f287d> in <module>
# ----> 1 data.isnull().sum()
#
# NameError: name 'data' is not defined

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7173426 entries, 0 to 7173425
# Data columns (total 11 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Unnamed: 0                 int64
#  1   name                       object
#  2   domain                     object
#  3   year founded               float64
#  4   industry                   object
#  5   size range                 object
#  6   locality                   object
#  7   country                    object
#  8   linkedin url               object
#  9   current employee estimate  int64
#  10  total employee estimate    int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 602.0+ MB

# %%
data2.columns = data2.columns.str.replace('\s+', '_')
##data2['year_founded'] = pd.to_datetime(data2['year_founded'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-cce9ae603372> in <module>
# ----> 1 data2.columns = data2.columns.str.replace('\s+', '_')
#       2 ##data2['year_founded'] = pd.to_datetime(data2['year_founded'])
#
# NameError: name 'data2' is not defined

# %%
df = pd.read_csv('data2.csv', index_col = 0,  nrows = 10000)
df.columns = df.columns.str.replace('\s+', '_')
##df['year_founded'] = pd.to_datetime(df['year_founded'])
df.rename(columns = { 'Unnamed:_0.1' : 'ID'}, inplace = True)
df.rename(columns = { 'year_founded' : 'Year'}, inplace = True)

##df['year'] = df['year_founded'].dt.year

# %%
df = df.drop(['linkedin_url'], axis = 1)
df = df.drop(['size_range'], axis = 1)

# %%
df
# Out:
#            ID                                            name  \
# 0     5872184                                             ibm
# 1     4425416                       tata consultancy services
# 2       21074                                       accenture
# 3     2309813                                         us army
# 4     1558607                                              ey
# ...       ...                                             ...
# 9995  3585785  university of chicago booth school of business
# 9996  2583172                      pantaloon retail india ltd
# 9997  1406043                                       nv energy
# 9998   955441                                          mining
# 9999  5571765                          university of stirling
#
#                 domain    Year                             industry  \
# 0              ibm.com  1911.0  information technology and services
# 1              tcs.com  1968.0  information technology and services
# ...

# %%
percent_null = data2.isna().sum().sort_values(ascending= False)/len(data2) * 100
percent_null
# Out:
# year_founded                 50.282529
# locality                     34.973874
# country                      32.748745
# domain                       23.010219
# industry                      4.042741
# name                          0.000042
# total_employee_estimate       0.000000
# current_employee_estimate     0.000000
# Unnamed:_0                    0.000000
# dtype: float64

# %%
percent_null.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
data2.size
# Out:
# 32098014

# %%
data2.year_founded.isnull().sum()
# Out:
# 3606980

# %%
data2.isna().sum().sort_values(ascending= False)
# Out:
# year_founded                 1235766
# total_employee_estimate            0
# current_employee_estimate          0
# country                            0
# locality                           0
# industry                           0
# domain                             0
# name                               0
# Unnamed:_0                         0
# dtype: int64

# %%
##df = df.dropna(subset=['year'])
##data2 = data2.dropna(subset=['locality'])
##data2 = data2.dropna(subset=['domain'])
##data2 = data2.dropna(subset=['industry', 'name'])
##df

# %%
data2.size
# Out:
# 33938478

# %%
#  Ask and Answer Questions About the Data
## How is the distribution of companies been over the years?
## How is the distribution of selected countries looks like that is evolved over the years?
## Plot a scatter plot to get an idea of how the industries evolved over the year after 1800 in a different country?
## Which is the company having the most spread?
## What are the top 15 countries where the companies are higher?
## What are the top 10 industries around the world?
## How are the different industries are distributed over the selected countries and industries?
## Which country has more number of IT industries with more number of employees?
## Which city has more number of IT industries with more number of employees within the country?
## Visualize the data of all countries using Folium Map?

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2535176 entries, 0 to 7173422
# Data columns (total 9 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   ID                         int64
#  1   name                       object
#  2   domain                     object
#  3   year_founded               datetime64[ns]
#  4   industry                   object
#  5   locality                   object
#  6   country                    object
#  7   current_employee_estimate  int64
#  8   total_employee_estimate    int64
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 193.4+ MB

# %%
## first characters of all the words are capitalized
data2.country = data2.country.str.title()
data2.industry = data2.industry.str.title()

# %%
df.boxplot(column=['Year'])
# Out:
# <AxesSubplot:>

# %%
df['year_founded'] = pd.to_datetime(df['year_founded'])

# %%
#### How is the distribution of companies been over the years?

##sns.distplot(df.year, kde = True , rug_kws={"color": "g"} )

sns.distplot(df['Year'], hist=True, kde=True, 
             bins=int(80/2), color = 'darkgreen', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2})
# Out:
# C:\Users\family\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Year', ylabel='Density'>

# %%
print('The mean of year : ', df.year.mean())
print('The median of year: ',df.year.median())
# Out:
# The mean of year :  1950.708846739582
# The median of year:  1966.0

# %%
## 3.How are the different industries scatterd in a country?
df
plt.scatter(industry, country)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-181-d849b706ff1a> in <module>
#       1 ## 3.How are the different industries scatterd in a country?
#       2 df
# ----> 3 plt.scatter(industry, country)
#
# NameError: name 'industry' is not defined

# %%
df2 = df[df.year > 1800]

earth = sorted(set(df["country"]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-187-164c7df6ba9e> in <module>
#       1 df2 = df[df.year > 1800]
#       2
# ----> 3 earth = sorted(set(df["country"]))
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
earth1 = set(df.country)

# %%
earth1 = sorted(earth)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-fbbb51cdb022> in <module>
# ----> 1 earth1 = sorted(earth)
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
import os
import plotly.graph_objects as go
fig=go.Figure()

region_plot_names = []
buttons=[]


for region_name in earth1:
  region = df[(df["country"]==region_name)]
  fig.add_trace(go.Scatter(x=region["industry"], y=region["year"], line={},mode='markers', visible=(region_name==default_state)))
  region_plot_names.extend([region_name])

for region_name in earth:
    buttons.append(dict(method='update',
                        label=region_name,
                        args = [{'visible': [region_name==r for r in region_plot_names]}]))
    
fig.update_layout(showlegend=False, updatemenus=[{"buttons": buttons, "direction": "down",  "showactive": True, "x": 0.8, "y": 1.50}])

fig.update_layout(template="plotly",title='<b>Industries evloved over the years</b>',
                 yaxis_title='<b>Year from 1800 to 2016</b>',
                 xaxis_title="<b>Industry</b>")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-5dc97251e85b> in <module>
#       9 for region_name in earth1:
# ...

# %%
india = df[df['country']== 'india]

# %%
plt.figure(figsize=(15,4))
plt.scatter(india.industry, india.year)
plt.xticks(rotation= 90)
plt.show()

# %%
new = df.groupby('country').sum()
new
# Out:
#                         ID     year  current_employee_estimate  \
# country
# algeria           16877594     9949                      18495
# angola             6339952     2001                       1213
# argentina         90809081    45043                      57938
# australia        423758750   251160                     444044
# austria           56064122    34718                      42907
# ...                    ...      ...                        ...
# united states  12226672761  6695403                   16768640
# uruguay           15282374     5758                       8062
# venezuela         19610497    13537                      20025
# vietnam            1036836     1999                       2105
# zimbabwe           8346207     3834                       2523
#
#                total_employee_estimate
# country
# algeria                          26574
# angola                            1641
# argentina                       100603
# ...

# %%
##new.reset_index(inplace = True)
new
# Out:
#     level_0  index        country           ID     year  \
# 0         0      0        algeria     16877594     9949
# 1         1      1         angola      6339952     2001
# 2         2      2      argentina     90809081    45043
# 3         3      3      australia    423758750   251160
# 4         4      4        austria     56064122    34718
# ..      ...    ...            ...          ...      ...
# 88       88     88  united states  12226672761  6695403
# 89       89     89        uruguay     15282374     5758
# 90       90     90      venezuela     19610497    13537
# 91       91     91        vietnam      1036836     1999
# 92       92     92       zimbabwe      8346207     3834
#
#     current_employee_estimate  total_employee_estimate
# 0                       18495                    26574
# 1                        1213                     1641
# 2                       57938                   100603
# 3                      444044                  1118085
# ...

# %%
new.country.to_list()
# Out:
# ['algeria',
#  'angola',
#  'argentina',
#  'australia',
#  'austria',
#  'bahrain',
#  'bangladesh',
#  'belgium',
#  'bermuda',
#  'brazil',
#  'canada',
#  'cayman islands',
#  'chile',
#  'china',
#  'colombia',
#  'costa rica',
#  'croatia',
#  'cyprus',
#  'czechia',
#  'denmark',
#  'dominican republic',
#  'egypt',
#  'estonia',
#  'ethiopia',
#  'fiji',
#  'finland',
#  'france',
#  'germany',
#  'ghana',
#  'greece',
#  'hong kong',
#  'hungary',
#  'iceland',
#  'india',
#  'indonesia',
#  'iran',
#  'ireland',
#  'israel',
#  'italy',
#  'jamaica',
#  'japan',
#  'jersey',
#  'jordan',
#  'kazakhstan',
#  'kenya',
#  'kuwait',
#  'lebanon',
#  'liechtenstein',
#  'luxembourg',
#  'malaysia',
#  'mexico',
#  'morocco',
#  'nan',
#  'netherlands',
#  'new zealand',
#  'nigeria',
#  'norway',
#  'oman',
#  'pakistan',
#  'palestine',
#  'panama',
#  'papua new guinea',
#  'peru',
#  'philippines',
#  'poland',
#  'portugal',
#  'puerto rico',
#  'qatar',
#  'romania',
# ...

# %%
## How does the distribution of selected countries looks like that has evolved over the years?

df.country.unique()
# Out:
# array(['united states', 'india', 'ireland', 'united kingdom', 'germany',
#        'finland', 'france', 'sweden', nan, 'netherlands', 'switzerland',
#        'china', 'canada', 'spain', 'brazil', 'saudi arabia', 'australia',
#        'turkey', 'czechia', 'united arab emirates', 'south korea',
#        'singapore', 'south africa', 'mexico', 'taiwan', 'japan',
#        'belgium', 'italy', 'colombia', 'algeria', 'norway', 'qatar',
#        'venezuela', 'indonesia', 'malaysia', 'denmark', 'luxembourg',
#        'hong kong', 'philippines', 'austria', 'chile', 'new zealand',
#        'kuwait', 'argentina', 'peru', 'greece', 'liechtenstein', 'oman',
#        'russia', 'pakistan', 'lebanon', 'uruguay', 'bermuda', 'iran',
#        'nigeria', 'egypt', 'poland', 'thailand', 'jamaica', 'morocco',
#        'romania', 'bangladesh', 'israel', 'jordan', 'kenya', 'sri lanka',
#        'puerto rico', 'kazakhstan', 'estonia', 'costa rica', 'portugal',
# ...

# %%
countries =  ['india', 'japan' , 'united kingdom', 'france']
new = df.loc[df['country'].isin(countries)]
new.sort_values(by='country',ascending=False,inplace=True)

# %%
new
# Out:
#            ID                                     name            domain  \
# 9999  5571765                   university of stirling        stir.ac.uk
# 3759  2263809                      plymouth university    plymouth.ac.uk
# 7463  5109969                                   markit        markit.com
# 3689  4333884                                   endava        endava.com
# 3696  4003429                                 centrica      centrica.com
# ...       ...                                      ...               ...
# 8209  4813778                                 fiducial       fiducial.fr
# 8208  5370008                            moët hennessy               NaN
# 6677  3002660                            solocal group  solocalgroup.com
# 2677  5978386                                     fnac          fnac.com
# 7985  6497665  societe generale private banking - sgpb               NaN
#
#       year_founded                             industry  \
# ...

# %%
years=list(set(new[new['country']=='india']['year_founded']) & set(new[new['country']=='united kingdom']['year_founded']) & set(new[new['country']=='japan']['year_founded']) & set(new[new['country']=='france']['year_founded']))
years2  = new.loc[new['year_founded'].isin(years)]
years2 = years2.sort_values(by = 'year_founded',ascending = True)
years2
# Out:
#            ID                                   name                  domain  \
# 9291  1747151     centre national d'études spatiales                 cnes.fr
# 7473   580228           toyo engineering corporation            toyo-eng.com
# 5589  1595311  indian institute of technology, delhi              iitd.ac.in
# 3198  3742425                                ranbaxy             ranbaxy.com
# 4888  1696249                   university of sussex            sussex.ac.uk
# ...       ...                                    ...                     ...
# 8884  3382459                                artelia        arteliagroup.com
# 9422  5844957          stonegate pub company limited       stonegatepubs.com
# 2884  4860506                                    jio                 jio.com
# 8671  1041902                        metro bank (uk)   metrobankonline.co.uk
# 9930  6306065            safran engineering services  safran-engineering.com
#
#       year_founded              industry  \
# ...

# %%
years2 = years2.sort_values(by = 'year_founded',ascending = True)
years2
# Out:
#            ID                                   name                  domain  \
# 9291  1747151     centre national d'études spatiales                 cnes.fr
# 7473   580228           toyo engineering corporation            toyo-eng.com
# 5589  1595311  indian institute of technology, delhi              iitd.ac.in
# 3198  3742425                                ranbaxy             ranbaxy.com
# 4888  1696249                   university of sussex            sussex.ac.uk
# ...       ...                                    ...                     ...
# 9422  5844957          stonegate pub company limited       stonegatepubs.com
# 2884  4860506                                    jio                 jio.com
# 1154  5387301                                publica     srnetconsulting.com
# 8671  1041902                        metro bank (uk)   metrobankonline.co.uk
# 9930  6306065            safran engineering services  safran-engineering.com
#
#       year_founded              industry  \
# ...

# %%
import os
import plotly.graph_objects as go
fig=go.Figure()

fig = px.bar(years2, 
           x="country", 
           y="total_employee_estimate",
           color="country",
           animation_frame="year_founded", range_y=[500, 60000])
fig.update_layout(template="plotly",title='<b>Trends in employees in different year</b>',
                 yaxis_title='<b>Number of Emploees</b>')
fig.show()
# Out:
# <div>                            <div id="7258f6cb-52a0-470d-bf99-e703762cf990" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7258f6cb-52a0-470d-bf99-e703762cf990")) {                    Plotly.newPlot(                        "7258f6cb-52a0-470d-bf99-e703762cf990",                        [{"alignmentgroup":"True","hovertemplate":"country=%{x}<br>year_founded=1961.0<br>total_employee_estimate=%{y}<extra></extra>","legendgroup":"france","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"france","offsetgroup":"france","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["france","france","france","france"],"xaxis":"x","y":[3775,37506,10998,4698],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"country=%{x}<br>yea
# ...

# %%
new[new['country']=='india'][['country','year_founded']]
# Out:
#      country  year_founded
# 9837   india        1970.0
# 9983   india        1988.0
# 9909   india        2014.0
# 9637   india        1961.0
# 9855   india        1978.0
# ...      ...           ...
# 4354   india        1995.0
# 5343   india        2008.0
# 4922   india        1984.0
# 5589   india        1961.0
# 5861   india        1988.0
#
# [311 rows x 2 columns]

# %%
years
# Out:
# [1988.0, 1961.0, 1997.0, 1968.0, 2003.0, 1974.0, 2009.0, 2010.0]

# %%
dfname
# Out:
#            ID                                            name  \
# 0     5872184                                             ibm
# 1     4425416                       tata consultancy services
# 2       21074                                       accenture
# 3     2309813                                         us army
# 4     1558607                                              ey
# ...       ...                                             ...
# 9995  3585785  university of chicago booth school of business
# 9996  2583172                      pantaloon retail india ltd
# 9997  1406043                                       nv energy
# 9998   955441                                          mining
# 9999  5571765                          university of stirling
#
#                 domain  year_founded                             industry  \
# 0              ibm.com        1911.0  information technology and services
# ...

# %%
df
# Out:
#            ID                                            name  \
# 0     5872184                                             ibm
# 1     4425416                       tata consultancy services
# 2       21074                                       accenture
# 3     2309813                                         us army
# 4     1558607                                              ey
# ...       ...                                             ...
# 9995  3585785  university of chicago booth school of business
# 9996  2583172                      pantaloon retail india ltd
# 9997  1406043                                       nv energy
# 9998   955441                                          mining
# 9999  5571765                          university of stirling
#
#                 domain  year_founded                             industry  \
# 0              ibm.com        1911.0  information technology and services
# ...

# %%
## Generate a word cloud image to check the spread of different company
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Start with one review:
text = df.name.values

# Create and generate a word cloud image:
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(str(text))

# Display the generated image:
plt.figure( figsize=(25,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
## Analyze column ['country']

df.country.nunique()
# Out:
# 94

# %%
## 7.What are the top 15 countries where the number of companies are higher?
count_companies =  df.groupby('country')['name'].count().sort_values(ascending = False).head(15)

# %%
count_companies= count_companies.reset_index()

# %%
count_companies.rename(columns ={'name' : 'count_company'} ,inplace = True)
count_companies
# Out:
#            country  count_company
# 0    united states           4179
# 1   united kingdom            612
# 2           canada            324
# 3            india            311
# 4           france            287
# 5           brazil            202
# 6      netherlands            199
# 7        australia            169
# 8          germany            144
# 9            italy            139
# 10           spain            127
# 11     switzerland            126
# 12          sweden             94
# 13    south africa             90
# 14         belgium             72

# %%
plt.bar(count_companies.country, count_companies.count_company)
plt.xticks(rotation= 90)
plt.title('Top 15 countries',fontsize=20)
plt.ylabel('Count of companies', fontsize=14)
plt.xlabel('Companies',fontsize=13)
plt.show()

# %%
sns.barplot(count_companies.country, count_companies.count_company)
plt.xticks(rotation= 90)
plt.title('Top 15 countries',fontsize=20)
plt.ylabel('Count of companies', fontsize=15)
plt.xlabel('Companies',fontsize=15)
plt.show()

# %%
## What are the top 10 industries around the world?

top_industry = df.industry.value_counts().head(10)
top_industry = top_industry.reset_index()
top_industry.rename(columns ={'index' : 'industry_name'} ,inplace = True)
top_industry
# Out:
#                          industry_name  industry
# 0                     higher education       935
# 1               hospital & health care       675
# 2            government administration       497
# 3  information technology and services       424
# 4                               retail       410
# 5                              banking       380
# 6                   financial services       371
# 7                   telecommunications       278
# 8                            insurance       271
# 9                         oil & energy       267

# %%
plt.figure( figsize=(10,5))

sns.set_style('darkgrid')
sns.set_palette('Set2')
sns.barplot(top_industry.industry, top_industry.industry_name)
##plt.xticks(rotation= 90)
plt.title('Top 10 Industry in World',fontsize=20)
plt.ylabel('Count of Industry', fontsize=25)
plt.xlabel('Industry',fontsize=25)
plt.show()
# Out:
# C:\Users\family\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
#   **9.How are the different industries are distributed over the selected countries?**

# %%
industries = ['higher education', 'hospital & health care','information technology and services','financial services', 'banking','insurance','oil & energy']
industry_df = df[df['industry'].isin(industries)]
countries = ['canada','united kingdom','india','france']
country_df = industry_df[industry_df['country'].isin(countries)]
country_df
# Out:
#            ID                       name                 domain    Year  \
# 1     4425416  tata consultancy services                tcs.com  1968.0
# 13    1454663                    infosys            infosys.com  1981.0
# 25    6021320                  capgemini          capgemini.com  1967.0
# 26    1373987         wipro technologies              wipro.com  1945.0
# 27    4968033                       hsbc               hsbc.com  1865.0
# ...       ...                        ...                    ...     ...
# 9881  3005504                 tullow oil          tullowoil.com  1985.0
# 9908  1800207         precision drilling  precisiondrilling.com     NaN
# 9916  4668864   robert gordon university              rgu.ac.uk  1992.0
# 9967  2813242                    valtech            valtech.com  1993.0
# 9999  5571765     university of stirling             stir.ac.uk  1967.0
#
#                                  industry  \
# 1     information technology and services
# ...

# %%
fig = px.bar(country_df, x="country", color="industry", barmode = 'group')
fig.update_layout(template="none",title='Types of indutries in countries')
fig.show()
# Out:
# <div>                            <div id="3371c2c3-3f5c-477e-bae6-b9ed43e9fca7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3371c2c3-3f5c-477e-bae6-b9ed43e9fca7")) {                    Plotly.newPlot(                        "3371c2c3-3f5c-477e-bae6-b9ed43e9fca7",                        [{"alignmentgroup":"True","hovertemplate":"industry=information technology and services<br>country=%{x}<br>count=%{y}<extra></extra>","legendgroup":"information technology and services","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"information technology and services","offsetgroup":"information technology and services","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["india","india","france","india","india","india","canada"
# ...

# %% [markdown]
# # Which country has more number of IT industries with more employees?

# %%
IT_industries = [
 'animation',
 'biotechnology',
 'computer & network security',
 'computer games',
 'computer hardware',
 'computer networking',
 'computer software',
 'consumer electronics',
 'defense & space',
 'e-learning',
 'industrial automation',
 'information services',
 'information technology And services',
 'internet',
 'mechanical or industrial engineering',
 'program development',
 'telecommunications',
 'wireless'
]

# %%
a = df[df.industry.isin(IT_industries)]
b
# Out:
#            ID                               name              domain    Year  \
# 8     3727010                          microsoft       microsoft.com  1975.0
# 9     3300741                               at&t             att.com  1876.0
# 10    5412257            united states air force        airforce.com  1947.0
# 19    4306268                             amazon          amazon.com  1994.0
# 20    5735407                              apple           apple.com  1976.0
# ...       ...                                ...                 ...     ...
# 9912   290938         kirloskar brothers limited  kirloskarpumps.com  1888.0
# 9943    74727                 telefonica moviles                 NaN     NaN
# 9945  6064702                       metricstream    metricstream.com  1999.0
# 9952  6198097                           nos sgps              nos.pt  2014.0
# 9962  6440432  tikona digital networks pvt. ltd.           tikona.in  2008.0
#
# ...

# %%
b = a.copy()

# %%
b = b.sort_values('current_employee_estimate',ascending = False)

b
# Out:
#            ID                               name              domain    Year  \
# 8     3727010                          microsoft       microsoft.com  1975.0
# 9     3300741                               at&t             att.com  1876.0
# 10    5412257            united states air force        airforce.com  1947.0
# 19    4306268                             amazon          amazon.com  1994.0
# 20    5735407                              apple           apple.com  1976.0
# ...       ...                                ...                 ...     ...
# 9912   290938         kirloskar brothers limited  kirloskarpumps.com  1888.0
# 9943    74727                 telefonica moviles                 NaN     NaN
# 9945  6064702                       metricstream    metricstream.com  1999.0
# 9952  6198097                           nos sgps              nos.pt  2014.0
# 9962  6440432  tikona digital networks pvt. ltd.           tikona.in  2008.0
#
# ...

# %%
fig = px.histogram(b, x='country', y='current_employee_estimate')
                         

fig.update_layout(template='plotly_dark',
                 title="IT industry in different country",
                 yaxis_title="Number of IT industrues",
                 xaxis_title="Country", 
                 legend_title ='Name of Country')
fig.show()
# Out:
# <div>                            <div id="b017c5f7-b90f-4d42-a3c8-d5370808965f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b017c5f7-b90f-4d42-a3c8-d5370808965f")) {                    Plotly.newPlot(                        "b017c5f7-b90f-4d42-a3c8-d5370808965f",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"country=%{x}<br>sum of current_employee_estimate=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":["united states","united states","united states","united states","united states","finland","united states","united kingdom","united states","china",null,"united states
# ...

# %%
sns.barplot(b.country, b.current_employee_estimate)
# Out:
# C:\Users\family\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='country', ylabel='current_employee_estimate'>

# %% [markdown]
# # Which city has more number of IT industries with more number of employees within the country?

# %%
b[['First','Last', 'third']] = df.locality.str.split(', ',expand=True)
b.rename(columns ={ 'First' : 'State', 'Last': 'City', 'third' : 'Country'}, inplace = True)

# %%
fig = px.histogram(b, x='Last', y='current_employee_estimate')
                         

fig.update_layout(template='plotly_dark',
                 title="IT industry in different country",
                 yaxis_title="Number of IT industrues",
                 xaxis_title="last", 
                 legend_title ='Name of Country')
fig.show()
# Out:
# <div>                            <div id="2579d46a-1c75-4a51-b3c9-4803f1a93c7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2579d46a-1c75-4a51-b3c9-4803f1a93c7d")) {                    Plotly.newPlot(                        "2579d46a-1c75-4a51-b3c9-4803f1a93c7d",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Last=%{x}<br>sum of current_employee_estimate=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":["washington","texas","texas","washington","california","uusimaa","california","west berkshire","california","guangdong",null,"maryland","new jersey","guangdong","\u00eel
# ...

# %% [markdown]
# # Create a TreeMap for country, state and city
# df

# %%
b[['city','state','country']] = b.locality.apply(lambda x: pd.Series(str(x).split(", ")))
b
# Out:
#            ID                               name              domain    Year  \
# 8     3727010                          microsoft       microsoft.com  1975.0
# 9     3300741                               at&t             att.com  1876.0
# 10    5412257            united states air force        airforce.com  1947.0
# 19    4306268                             amazon          amazon.com  1994.0
# 20    5735407                              apple           apple.com  1976.0
# ...       ...                                ...                 ...     ...
# 9912   290938         kirloskar brothers limited  kirloskarpumps.com  1888.0
# 9943    74727                 telefonica moviles                 NaN     NaN
# 9945  6064702                       metricstream    metricstream.com  1999.0
# 9952  6198097                           nos sgps              nos.pt  2014.0
# 9962  6440432  tikona digital networks pvt. ltd.           tikona.in  2008.0
#
# ...

# %%
df = df.dropna(subset=["country","state","city"])
fig = px.treemap(df,
               path=["country","state","city"],
               values= "current_employee_estimate",
               color_continuous_scale="RdBu")
fig.show()
# Out:
# <div>                            <div id="7c60615c-da16-43ed-ba10-c6889a01c2ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c60615c-da16-43ed-ba10-c6889a01c2ef")) {                    Plotly.newPlot(                        "7c60615c-da16-43ed-ba10-c6889a01c2ef",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>current_employee_estimate=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["denmark/syddanmark/a","sweden/vastra gotaland/a","denmark/syddanmark/aabenraa","germany/north rhine-westphalia/aachen","denmark/nordjylland/aalborg","germany/baden-wurttemberg/aalen","switzerland/aargau/aarburg","denmark/syddanmark/aaso","united kingdom/aberdeen city/aberdeen"
# ...
