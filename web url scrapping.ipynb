# %%
year = '2020'
str = 'https://www.basketball-reference.com/leagues/NBA_2020_per_game.html'

url = str.format(year)
url



##https://www.basketball-reference.com/leagues/NBA_2020_per_game.html
# Out:
# 'https://www.basketball-reference.com/leagues/NBA_2020_per_game.html'

# %%
years = [2016,2017,2018,2019,2020]
str  = 'https://www.basketball-reference.com/leagues/NBA_2020_per_game.html'

for year in years:
    url = str.format(year)
    print(url)
# Out:
# https://www.basketball-reference.com/leagues/NBA_2020_per_game.html
# https://www.basketball-reference.com/leagues/NBA_2020_per_game.html
# https://www.basketball-reference.com/leagues/NBA_2020_per_game.html
# https://www.basketball-reference.com/leagues/NBA_2020_per_game.html
# https://www.basketball-reference.com/leagues/NBA_2020_per_game.html

# %%
url = 'https://www.basketball-reference.com/leagues/NBA_2020_per_game.html'
url
# Out:
# 'https://www.basketball-reference.com/leagues/NBA_2020_per_game.html'

# %%
import pandas as pd

data = pd.read_html(url , header = 0)
data
# Out:
# [      Rk                    Player Pos Age   Tm   G  GS    MP   FG   FGA  ...  \
#  0      1              Steven Adams   C  26  OKC  63  63  26.7  4.5   7.6  ...
#  1      2               Bam Adebayo  PF  22  MIA  72  72  33.6  6.1  11.0  ...
#  2      3         LaMarcus Aldridge   C  34  SAS  53  53  33.1  7.4  15.0  ...
#  3      4            Kyle Alexander   C  23  MIA   2   0   6.5  0.5   1.0  ...
#  4      5  Nickeil Alexander-Walker  SG  21  NOP  47   1  12.6  2.1   5.7  ...
#  ..   ...                       ...  ..  ..  ...  ..  ..   ...  ...   ...  ...
#  672  525                Trae Young  PG  21  ATL  60  60  35.3  9.1  20.8  ...
#  673  526               Cody Zeller   C  27  CHO  58  39  23.1  4.3   8.3  ...
#  674  527              Tyler Zeller   C  30  SAS   2   0   2.0  0.5   2.0  ...
#  675  528                Ante Žižić   C  23  CLE  22   0  10.0  1.9   3.3  ...
#  676  529               Ivica Zubac   C  22  LAC  72  70  18.4  3.3   5.3  ...
#
# ...

# %%
len(data)
# Out:
# 1

# %%
data = data[0]

# %%
data
# Out:
#       Rk                    Player Pos Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0      1              Steven Adams   C  26  OKC  63  63  26.7  4.5   7.6  ...
# 1      2               Bam Adebayo  PF  22  MIA  72  72  33.6  6.1  11.0  ...
# 2      3         LaMarcus Aldridge   C  34  SAS  53  53  33.1  7.4  15.0  ...
# 3      4            Kyle Alexander   C  23  MIA   2   0   6.5  0.5   1.0  ...
# 4      5  Nickeil Alexander-Walker  SG  21  NOP  47   1  12.6  2.1   5.7  ...
# ..   ...                       ...  ..  ..  ...  ..  ..   ...  ...   ...  ...
# 672  525                Trae Young  PG  21  ATL  60  60  35.3  9.1  20.8  ...
# 673  526               Cody Zeller   C  27  CHO  58  39  23.1  4.3   8.3  ...
# 674  527              Tyler Zeller   C  30  SAS   2   0   2.0  0.5   2.0  ...
# 675  528                Ante Žižić   C  23  CLE  22   0  10.0  1.9   3.3  ...
# 676  529               Ivica Zubac   C  22  LAC  72  70  18.4  3.3   5.3  ...
#
# ...

# %%
import seaborn as sns

# %%
sns.distplot(data.PTS, kde = False)
# Out:
# C:\Users\family\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PTS'>

# %%
data = data.drop(data[data.Age =='Age'].index)

# %%
data.shape
# Out:
# (651, 30)

# %%
# Out:
#       Rk                    Player Pos Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0      1              Steven Adams   C  26  OKC  63  63  26.7  4.5   7.6  ...
# 1      2               Bam Adebayo  PF  22  MIA  72  72  33.6  6.1  11.0  ...
# 2      3         LaMarcus Aldridge   C  34  SAS  53  53  33.1  7.4  15.0  ...
# 3      4            Kyle Alexander   C  23  MIA   2   0   6.5  0.5   1.0  ...
# 4      5  Nickeil Alexander-Walker  SG  21  NOP  47   1  12.6  2.1   5.7  ...
# ..   ...                       ...  ..  ..  ...  ..  ..   ...  ...   ...  ...
# 672  525                Trae Young  PG  21  ATL  60  60  35.3  9.1  20.8  ...
# 673  526               Cody Zeller   C  27  CHO  58  39  23.1  4.3   8.3  ...
# 674  527              Tyler Zeller   C  30  SAS   2   0   2.0  0.5   2.0  ...
# 675  528                Ante Žižić   C  23  CLE  22   0  10.0  1.9   3.3  ...
# 676  529               Ivica Zubac   C  22  LAC  72  70  18.4  3.3   5.3  ...
#
# ...
