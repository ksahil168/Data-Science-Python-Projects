# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Netflix_Dataset.csv')
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
## is their any duplicate records in this dataset
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
data.drop(data.index[[6300, 6622]], inplace = True)

# %%
data.count()
# Out:
# Show_Id         7787
# Category        7787
# Title           7787
# Director        5399
# Cast            7069
# Country         7280
# Release_Date    7777
# Rating          7780
# Duration        7787
# Type            7787
# Description     7787
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
fig,ax = plt.subplots(figsize=(15,10)) 
sns.heatmap(data.isnull())
plt.show()

# %%
## for house of cards what is the show id  and who is the director
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data[data.Title == 'House of Cards'][['Director', 'Show_Id']]
# Out:
#                                                Director Show_Id
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...   s2833

# %%
data[data['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
data[data['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
## In which year highest no number of tv shows & Movies were released ? show with bar graph
##first changing the type of date column from object to datetime
data['Release_Date'] = pd.to_datetime(data['Release_Date'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   datetime64[ns]
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 669.5+ KB

# %%
##creating year column
data['Year'] = data['Release_Date'].dt.year

# %%
countmovies = data[['Year', 'Category']]

# %%
countmovies.groupby('Year')['Category'].value_counts().sort_values(ascending = False)
# Out:
# Year    Category
# 2019.0  Movie       1498
# 2020.0  Movie       1313
# 2018.0  Movie       1255
# 2017.0  Movie        864
# 2020.0  TV Show      697
# 2019.0  TV Show      656
# 2018.0  TV Show      430
# 2017.0  TV Show      361
# 2016.0  Movie        258
#         TV Show      185
# 2021.0  Movie         88
# 2015.0  Movie         58
#         TV Show       30
# 2021.0  TV Show       29
# 2014.0  Movie         19
# 2011.0  Movie         13
# 2014.0  TV Show        6
# 2013.0  Movie          6
#         TV Show        5
# 2012.0  Movie          3
# 2009.0  Movie          2
# 2010.0  Movie          1
# 2008.0  TV Show        1
#         Movie          1
# Name: Category, dtype: int64

# %%
data.Year.value_counts()
# Out:
# 2019.0    2154
# 2020.0    2010
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Year, dtype: int64

# %%
##bar graph 
fig,ax = plt.subplots(figsize=(15,10)) 

data.Year.value_counts().plot(kind= 'bar')
# Out:
# <AxesSubplot:>

# %%
## how many movies and tv shows are their in our dataset
data.groupby('Category').Category.count().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5379
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(data['Category'])
# Out:
# C:\Users\family\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
## Show all the movies that were released in year 2020
data[(data.Year == 2020) & (data.Category == 'Movie')]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
## Show all the title of tv shows that are released in india only

data[(data.Country == 'India') & (data.Category == 'TV Show')][['Title']].count()
# Out:
# Title    71
# dtype: int64

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
## show top 10 directors , who gave the highest number of tv shows & Movies  to netflix
data['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Jay Chapman               12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Ryan Polito                8
# Name: Director, dtype: int64

# %%
##Show all the records where category is Movies & Type is  Comedies || country is united kingdom
data.head(5)
data[(data.Category == 'Movies') & (data.Type == 'Comedies') | (data.Country == 'United Kingdom')]
# Out:
#      Show_Id Category                   Title           Director  \
# 19       s20    Movie                     '89                NaN
# 58       s59  TV Show             100% Hotter                NaN
# 82       s83    Movie     2036 Origin Unknown      Hasraf Dulull
# 85       s86  TV Show                21 Again                NaN
# 93       s94    Movie       27: Gone Too Soon  Simon Napier-Bell
# ...      ...      ...                     ...                ...
# 7670   s7669  TV Show  World War II in Colour                NaN
# 7671   s7670  TV Show  World's Busiest Cities                NaN
# 7688   s7687    Movie  XV: Beyond the Tryline   Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu        James Brown
# 7740   s7739  TV Show         Young Wallander                NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %%
data[data.Type.str.contains('Dramas')][['Type']]
# Out:
#                                                    Type
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                          Dramas, International Movies
# 4                                                Dramas
# 5       International TV Shows, TV Dramas, TV Mysteries
# 7                                                Dramas
# ...                                                 ...
# 7776                     Cult Movies, Dramas, Thrillers
# 7778                   Children & Family Movies, Dramas
# 7782   Dramas, Independent Movies, International Movies
# 7784                       Dramas, International Movies
# 7785     Dramas, International Movies, Music & Musicals
#
# [2812 rows x 1 columns]

# %%
## in how many movies Tom Cruise was Cast
data1 = data.dropna()
data1[data1['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description
# 3860  Through chance, human action, past history and...
# 5071  A fast-talking yuppie is forced to slow down w...

# %%
data[data.Cast == 'Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
## different rating defined by netflix

data1.Rating.nunique()
# Out:
# 14

# %%
## HOw many movies got TV-14 rating in canada

data[(data.Country == 'Canada') & (data.Rating == 'TV-14') ].groupby('Category').count()
# Out:
#           Show_Id  Title  Director  Cast  Country  Release_Date  Rating  \
# Category
# Movie          11     11        11     9       11            11      11
# TV Show        12     12         1     9       12            12      12
#
#           Duration  Type  Description
# Category
# Movie           11    11           11
# TV Show         12    12           12

# %%
## How many Tv shows got R Rating after year 2018
data[(data.Year > 2018) & (data.Rating == 'R') & (data.Category == 'TV Show')]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN   2019-04-25
#
#      Rating  Duration      Type  \
# 6437      R  1 Season  TV Shows
#
#                                             Description    Year
# 6437  Trapped at a stagecoach stop as a storm rages ...  2019.0

# %%
## what is the maximum duration of Movie/Netflix 
min = data[data['Duration'].str.contains('min')]
season = data[data['Duration'].str.contains('season')]

# %%
 s =  min['Duration'].str.split(' ', expand = True)
min['minute'] = s[0]
# Out:
# <ipython-input-126-9922e5c84880>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   min['minute'] = s[0]

# %%
season = data[data['Duration'].str.contains('Season')]
season
# Out:
# <ipython-input-133-eef582bea6fe>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   min['season'] = a[0]

# %%
a =  season['Duration'].str.split(' ', expand = True)
season['season'] = a[0]
# Out:
# <ipython-input-137-d3ae0936f415>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season['season'] = a[0]

# %%
min['minute'].max()
# Out:
# '99'

# %%
season['season'].max()
# Out:
# '9'

# %%
## which individual country has the higest number of  tv shows
data.groupby('Country')['Category'].value_counts()
# Out:
# Country                                              Category
# Argentina                                            Movie       34
#                                                      TV Show     16
# Argentina, Brazil, France, Poland, Germany, Denmark  Movie        1
# Argentina, Chile                                     Movie        1
# Argentina, Chile, Peru                               Movie        1
#                                                                  ..
# Venezuela                                            Movie        1
# Venezuela, Colombia                                  Movie        1
# Vietnam                                              Movie        5
# West Germany                                         Movie        1
# Zimbabwe                                             Movie        1
# Name: Category, Length: 773, dtype: int64

# %%
data.groupby('Category')['Country'].value_counts().sort_values(ascending = False)
# Out:
# Category  Country
# Movie     United States                                                                 1851
#           India                                                                          852
# TV Show   United States                                                                  705
#           United Kingdom                                                                 204
# Movie     United Kingdom                                                                 193
#                                                                                         ...
#           United Kingdom, Germany, Canada                                                  1
#           United Kingdom, France, United States, Belgium, Luxembourg, China, Germany       1
#           United Kingdom, France, United States, Belgium                                   1
#           United Kingdom, France, Germany, United States                                   1
# ...

# %%
category = data[data.Category == "TV Show"]
category.category.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-167-e5f6d3b043b7> in <module>
#       1 category = data[data.Category == "TV Show"]
# ----> 2 category.category.value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'category'

# %%
category.Country.value_counts()
# Out:
# United States                             705
# United Kingdom                            204
# Japan                                     157
# South Korea                               147
# India                                      71
#                                          ...
# Argentina, Spain                            1
# India, Germany, France                      1
# Ireland, United Kingdom, United States      1
# Italy, United Kingdom, France               1
# United Kingdom, Spain                       1
# Name: Country, Length: 183, dtype: int64

# %%
## How can we sort the dataset by year

data.sort_values(by = 'Year' ,ascending = True )
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...
