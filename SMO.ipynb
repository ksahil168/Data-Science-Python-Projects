# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()

# %%
dataset = pd.read_excel(pwd + "/SMO.xlsx", sheet_name= "edited")
dataset
# Out:
#      Respondent ID-         Start Date-           End Date-  Email Address-  \
# 0        5379192392 2021-01-22 12:01:17 2021-01-22 12:40:34             NaN
# 1        2658722536 2021-01-22 06:56:37 2021-01-22 07:34:10             NaN
# 2        4044163394 2021-01-22 06:35:18 2021-01-22 06:47:32             NaN
# 3        5535865599 2021-01-21 21:29:32 2021-01-21 21:40:24             NaN
# 4        3356802928 2021-01-21 17:26:39 2021-01-21 17:44:40             NaN
# ..              ...                 ...                 ...             ...
# 193      7940065082 2021-01-11 06:19:18 2021-01-11 06:32:59             NaN
# 194      5157705612 2021-01-11 06:19:14 2021-01-11 06:33:29             NaN
# 195      9920755555 2021-01-11 06:18:48 2021-01-11 06:27:27             NaN
# 196      6638341389 2021-01-11 06:19:01 2021-01-11 06:33:06             NaN
# 197      8114622230 2021-01-11 06:18:50 2021-01-11 06:26:46             NaN
#
#      First Name-  Last Name-  Custom Data 1-  \
# ...

# %%
dataset_modi = dataset.copy()

# %%
dataset_modi.columns
# Out:
# Index(['Respondent ID-', 'Start Date-', 'End Date-', 'Email Address-',
#        'First Name-', 'Last Name-', 'Custom Data 1-',
#        'Identify which division you work in.-Response',
#        'Identify which division you work in.-Other (please specify)',
#        'Which of the following best describes your position level?-Response',
#        'Which generation are you apart of?-Response',
#        'Please select the gender in which you identify.-Response',
#        'Which duration range best aligns with your tenure at your company?-Response',
#        'Which of the following best describes your employment type?-Response',
#        'Question 1-Response', 'Question 2-Response',
#        'Question 3-Open-Ended Response', 'Question 4-Response',
#        'Question 4-Other (please specify)', 'Question 5-Response 1',
#        'Question 5-Response 2', 'Question 5-Response 3',
#        'Question 5-Response 4', 'Question 5-Response 5',
# ...

# %%
columns_to_drop = ['Start Date-', 'End Date-', 'Email Address-','First Name-', 'Last Name-', 'Custom Data 1-']
columns_to_drop
# Out:
# ['Start Date-',
#  'End Date-',
#  'Email Address-',
#  'First Name-',
#  'Last Name-',
#  'Custom Data 1-']

# %%
dataset_modi = dataset_modi.drop(columns=columns_to_drop)
dataset_modi
# Out:
#      Respondent ID- Identify which division you work in.-Response  \
# 0        5379192392                                Infrastructure
# 1        2658722536                                       Finance
# 2        4044163394                                Infrastructure
# 3        5535865599                                Infrastructure
# 4        3356802928                               Port Operations
# ..              ...                                           ...
# 193      7940065082                                Infrastructure
# 194      5157705612                                       Finance
# 195      9920755555                               Port Operations
# 196      6638341389                                Infrastructure
# 197      8114622230                        Information Technology
#
#     Identify which division you work in.-Other (please specify)  \
# 0                                                  NaN
# ...

# %%
col_colmn=list(dataset_modi.columns)[:8]
rest_colmn= list(dataset_modi.columns)[8:]

# %%
dataset_melted = dataset_modi.melt(id_vars= col_colmn, value_vars =rest_colmn, var_name = "Question + Subquestion" , value_name= "Answer")  
dataset_melted
# Out:
#        Respondent ID- Identify which division you work in.-Response  \
# 0          5379192392                                Infrastructure
# 1          2658722536                                       Finance
# 2          4044163394                                Infrastructure
# 3          5535865599                                Infrastructure
# 4          3356802928                               Port Operations
# ...               ...                                           ...
# 17023      7940065082                                Infrastructure
# 17024      5157705612                                       Finance
# 17025      9920755555                               Port Operations
# 17026      6638341389                                Infrastructure
# 17027      8114622230                        Information Technology
#
#       Identify which division you work in.-Other (please specify)  \
# 0                                                    NaN
# ...

# %%
question_import = pd.read_excel(pwd + "/SMO.xlsx", sheet_name= "Question")
question_import
# Out:
#      Raw Question Raw Subquestion       Question  subquestion  \
# 0   Respondent ID             NaN  Respondent ID          NaN
# 1      Start Date             NaN     Start Date          NaN
# 2        End Date             NaN       End Date          NaN
# 3   Email Address             NaN  Email Address          NaN
# 4      First Name             NaN     First Name          NaN
# ..            ...             ...            ...          ...
# 95            NaN     Response 13    Question 29  Response 13
# 96            NaN     Response 14    Question 29  Response 14
# 97    Question 30      Response 1    Question 30   Response 1
# 98            NaN      Response 2    Question 30   Response 2
# 99            NaN      Response 3    Question 30   Response 3
#
#      Question + subquestion
# 0            Respondent ID-
# 1               Start Date-
# 2                 End Date-
# 3            Email Address-
# 4               First Name-
# ..                      ...
# ...

# %%
question = question_import.copy()
question.drop(columns=["Raw Question", "Raw Subquestion", "subquestion"], inplace= True)
question
# Out:
#          Question   Question + subquestion
# 0   Respondent ID           Respondent ID-
# 1      Start Date              Start Date-
# 2        End Date                End Date-
# 3   Email Address           Email Address-
# 4      First Name              First Name-
# ..            ...                      ...
# 95    Question 29  Question 29-Response 13
# 96    Question 29  Question 29-Response 14
# 97    Question 30   Question 30-Response 1
# 98    Question 30   Question 30-Response 2
# 99    Question 30   Question 30-Response 3
#
# [100 rows x 2 columns]

# %%
dataset_merged= pd.merge(left= dataset_melted, right= question,how ="left" , left_on = "Question + Subquestion", right_on="Question + subquestion")
print("original data", len(dataset_melted))
print("Merged data", len(dataset_merged))
dataset_merged.head()
# Out:
# original data 17028
# Merged data 17028
#    Respondent ID- Identify which division you work in.-Response  \
# 0      5379192392                                Infrastructure
# 1      2658722536                                       Finance
# 2      4044163394                                Infrastructure
# 3      5535865599                                Infrastructure
# 4      3356802928                               Port Operations
#
#   Identify which division you work in.-Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Which of the following best describes your position level?-Response  \
# 0                                              Staff
# 1                                              Staff
# ...

# %%
respondents = dataset_merged[dataset_merged["Answer"].notna()]
respondents = respondents.groupby("Question")["Respondent ID-"].nunique().reset_index()
respondents.rename(columns={"Respondent ID-":"Respondents"}, inplace = True)

respondents.head()
# Out:
#       Question  Respondents
# 0   Question 1          119
# 1  Question 10          198
# 2  Question 11          164
# 3  Question 12          114
# 4  Question 13          108

# %%
dataset_mergedtwo= pd.merge(left= dataset_merged, right= respondents,how ="left" , left_on = "Question", right_on="Question")
print("original data", len(dataset_merged))
print("Merged data", len(dataset_mergedtwo))
dataset_mergedtwo
# Out:
# original data 17028
# Merged data 17028
#        Respondent ID- Identify which division you work in.-Response  \
# 0          5379192392                                Infrastructure
# 1          2658722536                                       Finance
# 2          4044163394                                Infrastructure
# 3          5535865599                                Infrastructure
# 4          3356802928                               Port Operations
# ...               ...                                           ...
# 17023      7940065082                                Infrastructure
# 17024      5157705612                                       Finance
# 17025      9920755555                               Port Operations
# 17026      6638341389                                Infrastructure
# 17027      8114622230                        Information Technology
#
#       Identify which division you work in.-Other (please specify)  \
# ...

# %%
same_answer = dataset_merged #[dataset_merged["Answer"].notna()]
same_answer = same_answer.groupby(["Question + Subquestion","Answer"])["Respondent ID-"].nunique().reset_index()
same_answer.rename(columns={"Respondent ID-":"Same_answer"}, inplace = True)
same_answer
# Out:
#     Question + Subquestion    Answer  Same_answer
# 0      Question 1-Response  Answer 1           14
# 1      Question 1-Response  Answer 2           10
# 2      Question 1-Response  Answer 3           13
# 3      Question 1-Response  Answer 4           17
# 4      Question 1-Response  Answer 5           22
# ..                     ...       ...          ...
# 683  Question 9-Response 4  Answer 4           16
# 684  Question 9-Response 4  Answer 5           13
# 685  Question 9-Response 4  Answer 6           14
# 686  Question 9-Response 4  Answer 7           12
# 687  Question 9-Response 4  Answer 8           19
#
# [688 rows x 3 columns]

# %%
dataset_mergedthree = pd.merge(left= dataset_mergedtwo, right= same_answer,how ="left" , left_on = ["Question + Subquestion","Answer"], right_on=["Question + Subquestion","Answer"])
dataset_mergedthree["Same_answer"].fillna(0,inplace= True)
print("original data", len(dataset_mergedtwo))
print("Merged data", len(dataset_mergedthree))
dataset_mergedthree.head()
# Out:
# original data 17028
# Merged data 17028
#    Respondent ID- Identify which division you work in.-Response  \
# 0      5379192392                                Infrastructure
# 1      2658722536                                       Finance
# 2      4044163394                                Infrastructure
# 3      5535865599                                Infrastructure
# 4      3356802928                               Port Operations
#
#   Identify which division you work in.-Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Which of the following best describes your position level?-Response  \
# 0                                              Staff
# 1                                              Staff
# ...

# %%
"Identify which division you work in.-Response","Identify which division you work in.-Other (please specify)", "Which of the following best describes your position level?-Response" , "Which generation are you apart of?-Response" , "Please select the gender in which you identify.-Response", "Which duration range best aligns with your tenure at your company?-Response" , "Which of the following best describes your employment type?-Response" , "Question + Subquestion"

# %%
output = dataset_mergedthree.copy()
output.rename(columns={"Identify which division you work in.-Response": "Division","Identify which division you work in.-Other (please specify)":"Division 2", "Which of the following best describes your position level?-Response": "Position Level" , "Which generation are you apart of?-Response": "Generation" , "Please select the gender in which you identify.-Response": "Gender", "Which duration range best aligns with your tenure at your company?-Response": "Company Tenure" , "Which of the following best describes your employment type?-Response":"Employment Type" },inplace= True)
output
# Out:
#        Respondent ID-                Division Division 2   Position Level  \
# 0          5379192392          Infrastructure        NaN            Staff
# 1          2658722536                 Finance        NaN            Staff
# 2          4044163394          Infrastructure        NaN  Department Lead
# 3          5535865599          Infrastructure        NaN          Manager
# 4          3356802928         Port Operations        NaN          Manager
# ...               ...                     ...        ...              ...
# 17023      7940065082          Infrastructure        NaN  Department Lead
# 17024      5157705612                 Finance        NaN            Staff
# 17025      9920755555         Port Operations        NaN            Staff
# 17026      6638341389          Infrastructure        NaN          Manager
# 17027      8114622230  Information Technology        NaN            Staff
#
#                                   Generation      Gender Company Tenure  \
# ...

# %%
output.to_excel(pwd + "/final_output.xlsx", index= False)
